# %%
import numpy as np

# %%
R1=1001.1
R2=9005.1
Vm=1e-3 #V1-V2(R1/(R1+R2))
Vm_des=0.1e-3
n=5
V2=10

ui_Vm=Vm_des/np.sqrt(n)

uj_R1=(R1*0.01)/(100*np.sqrt(2))
uj_R2=(R2*0.01)/(100*np.sqrt(2))

#sacar con derivadads parciales y expandir

V1=Vm+V2*R1/(R2+R1)
print("%.5f"%V1)
# Out:
# 1.00148

# %%
#EN EL PUNTO 1
#aca vamos a tener el regulador alimentado a mucha tension

#EN EL PUNTO 4
#aca nos pide la regulacion de carga, entra una R, nos dice cual es la correinte de cara
#y nos da cuanto vale la carga 

#divisor kelvin: potenciometro o arreglo resistivo en ultra calidad, y con capacidad
#de dial buenisima. 
#0.1ppm - parte por millon (ppm)

# %%
#punto 3
Vm1 = 30e-3
Vbat = 10
div = 0.1

ui_div = 0
uj_div = (0.01*0.1e-6)/np.sqrt(3) #ppm es e-6 

#Vm = v_cal - divisor*Vbat
v_cal = Vm1 + div*Vbat
print(v_cal)
# Out:
# 1.03
