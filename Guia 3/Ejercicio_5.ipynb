# %%
import numpy as np
V=1 #V=Vth
Rth=0.5
Rv=10e6
Vi=1.007
errorV=0.2+(2/1007)*100

#incertidumbre tipo B
uj_V = ((errorV/100)*V)/np.sqrt(3)

#error de metodo
Em=(1/(1+(Rth/Rv)))-1
print("Error de metodo: ",Em)

#calculo V
Vi2=V*(1+Em)
print("V = %.3fV +- %.3fV"%(Vi2,uj_V))
# Out:
# Error de metodo:  -4.99999973646581e-08
# V = 1.000V +- 0.002V
