# %%
import numpy as np

I=7/1000
V=7.5
f=700e3

Z=V/I
print("Z=",Z)

R=1000
V=7
V2=7.18

desfase=0.05*360/1.42
print("Desfasaje:",desfase)

Xc=Z*np.sin(np.deg2rad(desfase))
print("Xc:",Xc) #Xc=1/wc

w=2*np.pi*f
c=1/(Xc*w)
print("C =",c)

r=Z*np.cos(np.deg2rad(desfase))
print("R:",r)
# Out:
# Z= 1071.4285714285713
# Desfasaje: 12.67605633802817
# Xc: 235.11269297299344
# C = 9.670435123768918e-10
# R: 1045.3139266634

# %%
I=7/1000
Vg=7.5
Vr=5
R=1e3
f=700e3

I=Vr/R
t_desfase=160e-9

Z=Vg/I
print("Z=",Z)

desfase=t_desfase*2*np.pi/1.42e-6
print("Desfasaje:",desfase)

Xc=Z*np.sin(desfase)
print("Xc:",Xc) #Xc=1/wc

w=2*np.pi*f
c=1/(Xc*w)
print("C =",c)
# Out:
# Z= 1500.0
# Desfasaje: 0.7079645416540379
# Xc: 975.4332116624054
# C = 2.330904891268798e-10

# %%
R=1000
t10=5.025e-6
t90=5.536e-6
Rise_time=t90-t10
c=Rise_time/(2.2*R)
print("C=",c)
# Out:
# C= 2.322727272727272e-10

# %%
R=1000
t10=5.028e-6
t90=5.574e-6
Rise_time=t90-t10
c=Rise_time/(2.2*R)
print("C=",c)
# Out:
# C= 2.4818181818181835e-10

# %%
#rise time de la punta
R=1049.88
t10=5.0024e-6
t90=5.0431e-6
Rise_timePunta=t90-t10
Rise_timeCorregido=np.sqrt(Rise_time**2 - Rise_timePunta**2)
c=Rise_timeCorregido/(2.2*R)
print("C =",c)
# Out:
# C = 2.357329818955548e-10
# 5.444809546715113e-07
