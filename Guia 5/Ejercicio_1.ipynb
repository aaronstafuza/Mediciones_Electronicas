# %%
import numpy as np

V=120e-3

#error voltimetro A,B,C
#mido 120mV con lo cual uso rango de 400mV y 200mV

e_V_a=(0.005+2/1200)
e_V_b=(0.004+1/120)
e_V_c=(0.003+1/12000)

print("Voltimetro A: %.3f"%e_V_a)
print("Voltimetro B: %.3f"%e_V_b)
print("Voltimetro C: %.3f"%e_V_c)
# Out:
# Voltimetro A: 0.007
# Voltimetro B: 0.012
# Voltimetro C: 0.003

# %% [markdown]
# Luego de calcular los errores, puedo decir que el voltimetro C es el que hay que elegir por tener un menor error.
