# %%
import numpy as np
# Out:
#   File "<ipython-input-3-eaa8bc7364a9>", line 1
#     import numpy as np
#                      ^
# SyntaxError: invalid character in identifier

# %%
import matplotlib.pyplot as plt
from matplotlib import style
plt.style.use('ggplot')
# %matplotlib inline

# %%
# Codigo para permitir acceso al Drive del Colaboratory:!pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Le damos permiso PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# (si estan su PC esto se cambia por el PATH al archivo y listo)
# Click derecho en el csv y obtenemos el link para compartir
LINK_SHAREABLE_CSV_1 = 'https://drive.google.com/file/d/1N7Mq9YqO3ACFQLaig0R3aOiYTMAaSVRc/view?usp=sharing'


# Cortamos el link y nos quedamos con el ID
fluff, id = LINK_SHAREABLE_CSV_1.split('=')
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('medicion1.csv')
