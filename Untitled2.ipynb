# %%
import numpy as np

f=10e6
R=1e6
C=25e-12

ch1=4
ch2=3
FDV=1
PP=10
divs_ch1=4
divs_ch2=3

error_lectura1=2*FDV*0.2 #Vpp 2 rayitas

Z=ch1/(ch2/R)
print(Z)

Xc=Z*np.sin(t_desfase*2*np.pi/T)
print(Xc)

# C=T/(Xc*2*np.pi)
# print("\nValor del capacitor:",C)
# Out:
# 1333333.3333333333
